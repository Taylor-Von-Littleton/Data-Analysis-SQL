# %%
# Import libraries
import pandas as pd
import seaborn as sns
import os
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

pd.options.mode.chained_assignment = None

# %%
#Verify path exists
path = r'C:\Users\Taylor Littleton\Downloads\Python Notebook\movies.csv.csv'
isFile = os.path.isfile(path)
print(isFile)
# Out:
# False

# %%
#Now we need to read in the data

df = pd.read_csv(r'C:\Users\Taylor Littleton\Downloads\Python Notebook\movies.csv.csv')

# %%
df.head(9)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# 1       July 2, 1980 (United States)    5.8    65000.0      Randal Kleiser
# ...

# %%
#get rid of empty values
df = df.dropna()

# %%
#now notice the output at the bottom change from 7668 rows to 5421 rows
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#add column with correct release year based off 'released' column
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

#df ---commented out df because github is having issues rendering my files. And I believe its do to its size.

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
#look at data types for columns
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes            int64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime          int64
# yearcorrect    float64
# dtype: object

# %%
#change data type dtypes values

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')
df['yearcorrect'] = df['yearcorrect'].astype(float)

# %%
# Are there any Outliers?
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
#drop any duplicatesaa

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
#df.sort_values(by=['gross'], inplace=False, ascending=False) --commenting out because of size constraints.

# %%
#look at all data
pd.set_option('display.max_rows', None)

# %%
#scatterplott with budget vs gross rev

#sns.regplot(x="gross", y="budget", data=df)
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score    votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000     Stanley Kubrick
# ...

# %%
#plot budget vs gross using seaborn --make correlation line blue

sns.regplot(x="gross", y="budget", data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
#lets view a basic correlation

df.corr() #works only on numerical fields
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
# Correlation Matrix between all numeric columns
#pearson is default correlation method. Others include kendall and spearman
df.corr(method ='pearson')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
#method2 kendall
df.corr(method ='kendall')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score        0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes        0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget       0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross        0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime      0.064824  0.292254  0.205344  0.231278  0.176979  1.000000
# yearcorrect  0.991304  0.043400  0.293044  0.213719  0.232372  0.064793
#
#              yearcorrect
# year            0.991304
# score           0.043400
# votes           0.293044
# budget          0.213719
# gross           0.232372
# runtime         0.064793
# yearcorrect     1.000000

# %%
#method3 spearman
df.corr(method = 'spearman')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score        0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes        0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget       0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross        0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime      0.095444  0.412155  0.300621  0.330794  0.257400  1.000000
# yearcorrect  0.998694  0.063674  0.422988  0.302535  0.340529  0.095507
#
#              yearcorrect
# year            0.998694
# score           0.063674
# votes           0.422988
# budget          0.302535
# gross           0.340529
# runtime         0.095507
# yearcorrect     1.000000

# %%
#create matrix chart for numeric correlation between column values.
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
#create a sequential value for each unique id based on datatype
#df_numerized = df

#for col_name in df_numerized.columns:
#    if(df_numerized[col_name].dtype == 'object'):
#        df_numerized[col_name] = df_numerized[col_name].astype('category')
#        df_numerized[col_name] = df_numerized[col_name].cat.codes
#                                                               
#df_numerized

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.169808  0.028413  0.965461  0.966086 -0.020083
# rating       0.169808  1.000000 -0.116507  0.179456  0.171063  0.036114
# genre        0.028413 -0.116507  1.000000  0.031765  0.031251 -0.027402
# year         0.965461  0.179456  0.031765  1.000000  0.996490 -0.014594
# released     0.966086  0.171063  0.031251  0.996490  1.000000 -0.019486
# score       -0.020083  0.036114 -0.027402 -0.014594 -0.019486  1.000000
# votes        0.297305  0.097619 -0.009983  0.323916  0.313254 -0.041981
# director     0.725411  0.096014  0.036671  0.747785  0.750825 -0.006583
# writer       0.791872  0.128909  0.033975  0.812386  0.809858 -0.021538
# star         0.695124  0.115694  0.045497  0.719373  0.720076  0.015108
# country      0.098110 -0.004547 -0.003314  0.095073  0.096807  0.016567
# budget       0.288955  0.203698  0.020893  0.319135  0.309616 -0.005493
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
